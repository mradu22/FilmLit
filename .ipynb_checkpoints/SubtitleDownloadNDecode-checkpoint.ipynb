# %%
import pandas as pd
import io, gzip
from codecs import decode
import pysrt
import datetime as dt
import base64
import re
import pdb
import dill
import numpy as np
import sys
from xmlrpc.client import ServerProxy
import os as os
import os.path
import json

# %%
with open('credentials.pkd','rb') as fp:
    credentials = dill.load(fp)
USER_AGENT=credentials['user']
USERNAME=credentials['user']
PASS=credentials['passw']

# %%
OPENSUBTITLES_SERVER = 'http://api.opensubtitles.org/xml-rpc'
LANGUAGE = 'en'

xmlrpc = ServerProxy(OPENSUBTITLES_SERVER,allow_none=True)
data = xmlrpc.LogIn(USERNAME, PASS, LANGUAGE, USER_AGENT)
status=data.get('status')
if status != '200 OK':
    print('Could not log in. Something is wrong... ')
    print("data.get('status')")
    token = None
else:
    token = data.get('token')
    print('Logged in. Acquired token = {}'.format(token))
print('------------------Current Stats-----------------')
for key,item in xmlrpc.ServerInfo(token)['download_limits'].items():
    print('{}: {}'.format(key,item))
# Out:
# Logged in. Acquired token = QGCxFedopuCVqYArI9tOPtIJc-0
# ------------------Current Stats-----------------
# global_24h_download_limit: 200
# client_ip: 216.174.124.203
# limit_check_by: user_id
# user_id: 5937493
# client_24h_download_count: 2
# client_download_quota: 998
# client_24h_download_limit: 1000

# %%
with open('movie_DB_1_7_2018.pkd', 'rb') as fp:
    movie_database = dill.load(fp)

# %%
LA=[item['imdb_id'] for item in movie_database[7777:7790]]

# %%
def filter_one(sr_one):
    if not sr_one:
        return []
    else:
        sr=[(item['SubDownloadsCnt'],item['SubRating'],item['IDSubtitleFile'],item['IDMovieImdb']) for item in sr_one 
         if item['SubFormat']=='srt' if not re.findall('.*[^a-zA-Z]cd[^a-zA-Z]',item['MovieReleaseName'].lower())]
        sr_sort=sorted(sr, key=lambda x: -int(x[0]))
        result=tuple([fill_id(sr_sort[0][3])]+[item[2] for item in sr_sort[0:3]])
        return result #returns a tuple 

def fill_id(string):
    #opensubtitles removes the 'tt' and all leading 0's . this function replaces them.
    while len(string) < 7:
        string = '0' + string
    return 'tt' + string
    
def search_imdbid(list_imdbids):
    search_params=[{'sublanguageid':'eng','imdbid':item.strip('tt')} for item in list_imdbids]
    search_data=xmlrpc.SearchSubtitles(token,search_params)
    sr=[]
    try_num=0
    while sr==[]:
        if search_data['status'] == '200 OK':
            sd=search_data['data'] #a long list of search results by imdb_ids
            uniq_id=list(set([item['IDMovieImdb'] for item in sd]))
            sr=[filter_one([item for item in sd if item['IDMovieImdb'] == idnum]) for idnum in uniq_id] 
            #filter_one takes a list of search results for a single imdbid and returns a tuple (imdbid, subid1,subid2,subid3)
            #the above 3 lines will partition the search results sd into a list of lists where each inner list is for one imdbid
            if sr==[]: #sr will be an empty list if no results are found (it is possible)
                return []         
        else:
            if try_num==3: #gives up after 3 times
                print('Tried 3 times. Giving up.')
                return 
            try_num=try_num+1
            print('Error Code: {} Retrying in 10 seconds.'.format(search_data['status']))    
            time.sleep(10)
    return sr

# %%
search_imdbid(LA)
# Out:
# [('tt2788716', '1954759522', '1954746074', '1954746470'),
#  ('tt0375568', '1952236163', '1952290942', '1952238223'),
#  ('tt1172233', '1952255654', '1952253587', '1952253588'),
#  ('tt1213644', '1951998788', '1951997839', '1951998374'),
#  ('tt0077294', '1951646814', '1952210619', '1953147612'),
#  ('tt0149215', '1953436633', '1954806221'),
#  ('tt1185371', '1953078912', '1953123197', '1955293588'),
#  ('tt0316465', '1951671683', '206324', '78023'),
#  ('tt0089755', '1952209762', '1952178596', '1953780571'),
#  ('tt1645089', '1952792733', '1952799830', '1952801541'),
#  ('tt2103217', '1953507844', '1953510751', '1953543455'),
#  ('tt0227538', '316214', '1953418483', '1952148958')]

# %%
def search_imdbid(s_imdb):
    #s_imdb='1055369'
    search_data=xmlrpc.SearchSubtitles(token,[{'sublanguageid': 'eng','imdbid': s_imdb}])
    data=search_data['data']
    return data

def find_best_file(data,rank):
    best=[]
    for i in range(0,len(data)):
        if data[i]['SubFormat'] == 'srt' and 'cd' not in data[i]['SubFileName'].lower():
            #print(data[i]['SubFileName'].lower(),data[i]['IDSubtitleFile'],float(data[i]['SubRating'])*float(data[i]['SubDownloadsCnt']))
            #best.append(float(data[i]['SubRating'])*float(data[i]['SubDownloadsCnt'])) 
            best.append(float(data[i]['SubDownloadsCnt']))    
        else:
            best.append(0)
    
    if best:
        best_sub_id=data[best.index(max(best))]['IDSubtitleFile'] 
        best[best.index(max(best))]=0
        sbest_sub_id=data[best.index(max(best))]['IDSubtitleFile'] 
        best[best.index(max(best))]=0
        tbest_sub_id=data[best.index(max(best))]['IDSubtitleFile'] 
        #print('Found the best one', best_sub_id)
    if rank==1 and best:
        return best_sub_id
    elif rank==2 and best:
        return sbest_sub_id
    elif rank==3 and best:
        return tbest_sub_id
    else:
        return False

def download_sub(best_sub_id):
    if best_sub_id:
        #best_sub_id='1952195191'
        down_data=xmlrpc.DownloadSubtitles(token, [best_sub_id])
        if down_data['status'] !='200 OK':
            print('--------------------- Error Message:')
            print(down_data['status'])
            exit("Exiting Program Now. Come back Tomorrow. ")
        return down_data
    else:
        return False
    
def decode_parse(down_data,imdb_id):
    if down_data:
        compressed_subdata = decode(bytearray(down_data['data'][0]['data'].encode("utf-8")),'base64')
        sub_text = gzip.GzipFile(fileobj=io.BytesIO(compressed_subdata)).read()
        #parse it and store it into a DataFrame with three columns, starttime, endtime, and line
        sub_text_str = str(sub_text)
        snew = sub_text_str.replace("\\n","\n").replace("\\r","\r").replace("</i>","").replace("<i>-","").replace("<i>","").replace("\\","")
        subs=list(filter(None, snew.split('\r\n')))
        subs=[x for x in subs if not x.isdigit()]
        if subs[0][0]=='b':
            subs.pop(0)

        starttimes=[]
        endtimes=[]
        words=[]
        #"-->" in line
        prevLineWasWords =False
        for line in subs:
            line=line.strip()
            if "-->" in line:
                starttimes.append(line[:8])
                endtimes.append(line[17:25])
            elif len(line) > 1:
                    if prevLineWasWords:
                            words[len(words)-1] = words[len(words)-1] + " " + line
                    else:
                            words.append(line)
                    prevLineWasWords = True
                    continue
            prevLineWasWords = False  

        #this needs to be made better but for now we need these to be same length so it will have to do
        trim_by=min([len(starttimes),len(endtimes),len(words)])
        starttimes=starttimes[0:trim_by]
        endtimes=endtimes[0:trim_by]
        words=words[0:trim_by]

        imdb_idi=[imdb_id]
        linfo=['StartTime','EndTime','Line']
        index=pd.MultiIndex.from_product([imdb_idi,linfo],names=['IDs','LData'])
        plines=pd.DataFrame(columns=index)


        s1 = pd.Series(starttimes)
        s2 = pd.Series(endtimes)
        s3 = pd.Series(words)
        plines.loc[:,(imdb_id,'StartTime')] = s1.values
        plines.loc[:,(imdb_id,'EndTime')] = s2.values
        plines.loc[:,(imdb_id,'Line')] = s3.values
        return plines
    else:
        return False

#def populate_db(list):
    #input is a list of IMDB_IDS
    #open existing database of subtitles
    #check if each id is in there
        #if not download it and add it to the list (do this 20 at a time)
        #if yes then move on

# %%
##open existing database and download shit from it
if os.path.isfile('movbaseB.h5'):
    movdb=pd.read_hdf('movbaseB.h5', 'imdb_id')
else:
    print('Cannot find file movbaseB!')

# %%
batch=movdb[1000:1350]
len(batch)
# Out:
# 350

# %%
#run this PER GENRE
#input is a list of imdb_id's which can come from whatever
#probably should come from a subset of movdb
if os.path.isfile('Sub_data.h5'):
    Sub_data=pd.read_hdf('Sub_data.h5', 'subs')
else:
    print('Cannot find file Sub_data! Making new one.')

for item in batch['imdb_id']:
    if item not in Sub_data.columns.levels[0]:
            one_sub=decode_parse(download_sub(find_best_file(search_imdbid(item),1)),item)
            try:
                if not one_sub:
                    print('COULDNT FIND SUBS FOR {}.   Title:  {} '.format(item,batch[batch['imdb_id'] == item]['Title'].values[0]))
                    continue
            except:
                if len(one_sub) < 2:
                    one_sub=decode_parse(download_sub(find_best_file(search_imdbid(item),2)),item)

                    if len(one_sub) < 2:
                        one_sub=decode_parse(download_sub(find_best_file(search_imdbid(item),3)),item)

                        if len(one_sub) <2:
                            print('First 3 subs for {} were bad. Not going any further. Title:  {} '.format(item,batch[batch['imdb_id'] == item]['Title'].values[0]))
                            continue



                Sub_data=pd.concat([Sub_data,one_sub], axis=1)
                Sub_data=Sub_data.fillna('')
                Sub_data.to_hdf('Sub_data.h5', 'subs', mode='w')
                print('Downloaded subs for {}.   Title:  {} '.format(item,batch[batch['imdb_id'] == item]['Title'].values[0]))

    else:
        print('Encountered double of {}. Title:  {}'.format(item,batch[batch['imdb_id'] == item]['Title'].values[0]))
        continue
        
print('Done. Writing Sub_data to file.')
# Out:
# Downloaded subs for 3387542.   Title:  The Forest
# Downloaded subs for 0130018.   Title:  I Still Know What You Did Last Summer
# Downloaded subs for 1311067.   Title:  Halloween II
# Downloaded subs for 0433386.   Title:  The Grudge 2
# Downloaded subs for 0099528.   Title:  The Exorcist III
# Downloaded subs for 0097368.   Title:  The Fly II
# Downloaded subs for 0450345.   Title:  The Wicker Man
# Downloaded subs for 0091419.   Title:  Little Shop of Horrors
# Downloaded subs for 1053859.   Title:  The Grudge 3
# Downloaded subs for 0192731.   Title:  Urban Legends: Final Cut
# Downloaded subs for 0220506.   Title:  Halloween: Resurrection
# Downloaded subs for 0475944.   Title:  The Covenant
# Downloaded subs for 0105217.   Title:  Raising Cain
# Downloaded subs for 0155975.   Title:  Psycho
# Downloaded subs for 1270761.   Title:  Don't Be Afraid of the Dark
# Downloaded subs for 0083972.   Title:  Friday the 13th Part III
# Downloaded subs for 0096734.   Title:  The 'Burbs
# Downloaded subs for 2752758.   Title:  Devil's Due
# Downloaded subs for 0099253.   Title:  Child's Play 2
# Downloaded subs for 0498353.   Title:  Hostel: Part II
# Downloaded subs for 0452702.   Title:  Vacancy
# Downloaded subs for 0089200.   Title:  Ghoulies
# Downloaded subs for 0101917.   Title:  Freddy's Dead: The Final Nightmare
# COULDNT FIND SUBS FOR 5109784.   Title:  mother!
# Downloaded subs for 0086154.   Title:  Psycho II
# Downloaded subs for 0088993.   Title:  Day of the Dead
# Downloaded subs for 0120004.   Title:  The Relic
# Downloaded subs for 0074285.   Title:  Carrie
# Downloaded subs for 1314655.   Title:  Devil
# Downloaded subs for 0063522.   Title:  Rosemary's Baby
# Downloaded subs for 0219653.   Title:  Dracula 2000
# Downloaded subs for 0087298.   Title:  Friday the 13th: The Final Chapter
# Downloaded subs for 0844708.   Title:  The Last House on the Left
# Downloaded subs for 0093437.   Title:  The Lost Boys
# Downloaded subs for 0104692.   Title:  The Lawnmower Man
# Downloaded subs for 0054215.   Title:  Psycho
# Downloaded subs for 0082010.   Title:  An American Werewolf in London
# Downloaded subs for 0080661.   Title:  Dressed to Kill
# Downloaded subs for 1131734.   Title:  Jennifer's Body
# Downloaded subs for 0072271.   Title:  The Texas Chain Saw Massacre
# Downloaded subs for 0076009.   Title:  Exorcist II: The Heretic
# Downloaded subs for 1389139.   Title:  When the Bough Breaks
# Downloaded subs for 0303816.   Title:  Cabin Fever
# Downloaded subs for 0105428.   Title:  Sleepwalkers
# Downloaded subs for 0335121.   Title:  Godsend
# Downloaded subs for 0365748.   Title:  Shaun of the Dead
# Downloaded subs for 0063350.   Title:  Night of the Living Dead
# Downloaded subs for 0089686.   Title:  A Nightmare on Elm Street Part 2: Freddy's Revenge
# Downloaded subs for 0454919.   Title:  Pulse
# Downloaded subs for 0086491.   Title:  Twilight Zone: The Movie
# Downloaded subs for 0083907.   Title:  The Evil Dead
# Downloaded subs for 0116365.   Title:  The Frighteners
# Downloaded subs for 0795351.   Title:  Case 39
# Downloaded subs for 0295700.   Title:  Wrong Turn
# Downloaded subs for 0905372.   Title:  The Thing
# Downloaded subs for 0416315.   Title:  Wolf Creek
# Downloaded subs for 1232783.   Title:  Sorority Row
# Downloaded subs for 0441796.   Title:  Stay Alive
# Downloaded subs for 0119081.   Title:  Event Horizon
# Downloaded subs for 4030600.   Title:  The Bye Bye Man
# Downloaded subs for 0118604.   Title:  An American Werewolf in Paris
# Downloaded subs for 4731136.   Title:  A Cure for Wellness
# Downloaded subs for 0077394.   Title:  Damien: Omen II
# Downloaded subs for 2339741.   Title:  The Woman in Black 2: Angel of Death
# Downloaded subs for 0099871.   Title:  Jacob's Ladder
# Downloaded subs for 0116367.   Title:  From Dusk Till Dawn
# Downloaded subs for 0103919.   Title:  Candyman
# Downloaded subs for 1772240.   Title:  Apollo 18
# Downloaded subs for 0082495.   Title:  Halloween II
# Downloaded subs for 0087800.   Title:  A Nightmare on Elm Street
# Downloaded subs for 0119675.   Title:  Mimic
# Downloaded subs for 0382628.   Title:  Dark Water
# Downloaded subs for 0455960.   Title:  The Hitcher
# Downloaded subs for 2387433.   Title:  Dark Skies
# Downloaded subs for 0462322.   Title:  Grindhouse
# Downloaded subs for 0077681.   Title:  The Hills Have Eyes
# Downloaded subs for 0089175.   Title:  Fright Night
# Downloaded subs for 1438176.   Title:  Fright Night
# Downloaded subs for 0387575.   Title:  Seed of Chucky
# Downloaded subs for 0115963.   Title:  The Craft
# Downloaded subs for 1228987.   Title:  Let Me In
# Downloaded subs for 0077745.   Title:  Invasion of the Body Snatchers
# Downloaded subs for 0077588.   Title:  The Fury
# Downloaded subs for 0045888.   Title:  House of Wax
# Downloaded subs for 0099578.   Title:  The First Power
# Downloaded subs for 0455760.   Title:  Dead Silence
# Downloaded subs for 0097981.   Title:  A Nightmare on Elm Street 5: The Dream Child
# COULDNT FIND SUBS FOR 0068837.   Title:  The Legend of Boggy Creek
# Downloaded subs for 0089173.   Title:  Friday the 13th: A New Beginning
# Downloaded subs for 0082418.   Title:  Friday the 13th Part 2
# Downloaded subs for 0454082.   Title:  Black Christmas
# Downloaded subs for 0080749.   Title:  The Fog
# Downloaded subs for 0085333.   Title:  Christine
# Downloaded subs for 0085382.   Title:  Cujo
# Downloaded subs for 0164181.   Title:  Stir of Echoes
# Downloaded subs for 0083767.   Title:  Creepshow
# Downloaded subs for 0085407.   Title:  The Dead Zone
# Downloaded subs for 1188729.   Title:  Pandorum
# Downloaded subs for 0103956.   Title:  Child's Play 3
# Downloaded subs for 0082377.   Title:  Omen III: The Final Conflict
# COULDNT FIND SUBS FOR 0075333.   Title:  To Fly!
# Downloaded subs for 1116184.   Title:  Jackass 3D
# Encountered double of 0393597. Title:  Earth
# Encountered double of 1702443. Title:  Justin Bieber: Never Say Never
# Encountered double of 0113676. Title:  The Living Sea
# Encountered double of 0120661. Title:  Everest
# Encountered double of 0493430. Title:  Jackass Number Two
# Encountered double of 0322802. Title:  Jackass: The Movie
# Encountered double of 0087355. Title:  Grand Canyon: The Hidden Secrets
# Encountered double of 0497116. Title:  An Inconvenient Truth
# First 3 subs for 0145921 were bad. Not going any further. Title:  Mysteries of Egypt
# Downloaded subs for 0310793.   Title:  Bowling for Columbine
# Downloaded subs for 0066580.   Title:  Woodstock
# Downloaded subs for 2247692.   Title:  2016: Obama's America
# Downloaded subs for 2215719.   Title:  Katy Perry: Part of Me
# Downloaded subs for 2609912.   Title:  Kevin Hart: Let Me Explain
# Downloaded subs for 0390521.   Title:  Super Size Me
# Downloaded subs for 0386032.   Title:  Sicko
# Downloaded subs for 0099158.   Title:  Blue Planet
# COULDNT FIND SUBS FOR 0892375.   Title:  U2 3D
# Downloaded subs for 0245280.   Title:  Michael Jordan to the Max
# Downloaded subs for 0765128.   Title:  Oceans
# Downloaded subs for 1922612.   Title:  Glee: The Concert Movie
# Downloaded subs for 1232207.   Title:  Capitalism: A Love Story
# Downloaded subs for 0297144.   Title:  Ghosts of the Abyss
# Downloaded subs for 0163639.   Title:  IMAX: Galapagos 3D
# Downloaded subs for 3660770.   Title:  Monkey Kingdom
# Downloaded subs for 1223236.   Title:  African Cats
# COULDNT FIND SUBS FOR .   Title:  The Story Of Short Stack
# Downloaded subs for 0379557.   Title:  Touching the Void
# Downloaded subs for 0337587.   Title:  Bugs!
# Downloaded subs for 5646136.   Title:  Hillary's America: The Secret History of the D..
# Downloaded subs for 0425598.   Title:  Dave Chappelle's Block Party
# Downloaded subs for 0399877.   Title:  What the #$*! Do We (K)now!?
# Downloaded subs for 2870648.   Title:  Amy
# Downloaded subs for 0088249.   Title:  Terror in the Aisles
# Downloaded subs for 1424432.   Title:  Senna
# Downloaded subs for 1645089.   Title:  Inside Job
# Downloaded subs for 0110057.   Title:  Hoop Dreams
# Downloaded subs for 0343121.   Title:  Tupac: Resurrection
# Downloaded subs for 1680059.   Title:  Born to Be Wild
# Downloaded subs for 1091617.   Title:  Expelled: No Intelligence Allowed
# Downloaded subs for 0996382.   Title:  Dolphins and Whales: Tribes of the Ocean
# COULDNT FIND SUBS FOR .   Title:  The Story Of Short Stack
# Downloaded subs for 0098213.   Title:  Roger & Me
# Downloaded subs for 1664894.   Title:  Cave of Forgotten Dreams
# Downloaded subs for 0226648.   Title:  Wolves
# Downloaded subs for 0088178.   Title:  Stop Making Sense
# Downloaded subs for 1587707.   Title:  Exit Through the Gift Shop
# Downloaded subs for 0379225.   Title:  The Corporation
# Downloaded subs for 1529567.   Title:  Sea Rex 3D: Journey to a Prehistoric World
# COULDNT FIND SUBS FOR 4266692.   Title:  Drain the Bermuda Triangle
# Downloaded subs for 0100332.   Title:  Paris is Burning
# Downloaded subs for 0388789.   Title:  Born into Brothels
# COULDNT FIND SUBS FOR 3635920.   Title:  D-Day: Normandy 1944
# Downloaded subs for 0109508.   Title:  Crumb
# Downloaded subs for 0389326.   Title:  Riding Giants
# Downloaded subs for 3882074.   Title:  The Eagle Huntress
# Downloaded subs for 0342172.   Title:  Capturing the Friedmans
# Downloaded subs for 1584016.   Title:  Catfish
# Downloaded subs for 4044364.   Title:  Citizenfour
# Downloaded subs for 1155592.   Title:  Man on Wire
# Downloaded subs for 0328962.   Title:  Comedian
# Downloaded subs for 0118147.   Title:  When We Were Kings
# Downloaded subs for 3065132.   Title:  He Named Me Malala
# Downloaded subs for 0391024.   Title:  Control Room
# Downloaded subs for 1772925.   Title:  Jiro Dreams of Sushi
# First 3 subs for 0264578 were bad. Not going any further. Title:  The Endurance: Shackleton's Legendary Antarcti..
# COULDNT FIND SUBS FOR 5855378.   Title:  Billy Yeager The Ineffable Enigma
# Downloaded subs for 2545428.   Title:  Meru
# COULDNT FIND SUBS FOR 0084156.   Title:  It Came from Hollywood
# COULDNT FIND SUBS FOR 0221809.   Title:  Ayurveda: Art of Being
# Downloaded subs for 2545118.   Title:  Blackfish
# COULDNT FIND SUBS FOR 0083193.   Title:  This Is Elvis
# COULDNT FIND SUBS FOR 0421139.   Title:  Mars: Pioneering the Planet
# Downloaded subs for 1229360.   Title:  It Might Get Loud
# COULDNT FIND SUBS FOR 0436613.   Title:  Murderball
# COULDNT FIND SUBS FOR 0085809.   Title:  Koyaanisqatsi
# COULDNT FIND SUBS FOR 1383252.   Title:  Sbirri
# Downloaded subs for 0489037.   Title:  Who Killed the Electric Car?
# Downloaded subs for 2714900.   Title:  Finding Vivian Maier
# COULDNT FIND SUBS FOR 1067777.   Title:  The Possessed
# Downloaded subs for 0303353.   Title:  The Kid Stays in the Picture
# Downloaded subs for 0912593.   Title:  No End in Sight
# Downloaded subs for 1559549.   Title:  Restrepo
# Downloaded subs for 1621444.   Title:  Bill Cunningham New York
# Downloaded subs for 1579361.   Title:  Chasing Ice
# Downloaded subs for 2415458.   Title:  The Wolfpack
# Downloaded subs for 1500516.   Title:  Videocracy
# Downloaded subs for 1313104.   Title:  The Cove
# COULDNT FIND SUBS FOR 0390538.   Title:  Tarnation
# COULDNT FIND SUBS FOR 1334479.   Title:  Yoo Hoo Mrs Goldberg
# Downloaded subs for 1286821.   Title:  More Than a Game
# COULDNT FIND SUBS FOR 1976608.   Title:  Sholem Aleichem: Laughing In The Darkness
# COULDNT FIND SUBS FOR 0119107.   Title:  Fast, Cheap & Out of Control
# Downloaded subs for 1114277.   Title:  Up the Yangtze
# Downloaded subs for 0097372.   Title:  For All Mankind
# Downloaded subs for 0455475.   Title:  First Descent
# Downloaded subs for 2126403.   Title:  The Stone Roses: Made of Stone
# Downloaded subs for 0124295.   Title:  The Big One
# Downloaded subs for 2125666.   Title:  The Queen of Versailles
# Downloaded subs for 3264102.   Title:  Red Army
# Downloaded subs for 1567233.   Title:  Forks Over Knives
# Downloaded subs for 0418753.   Title:  Inside Deep Throat
# Downloaded subs for 1743720.   Title:  The Greatest Movie Ever Sold
# COULDNT FIND SUBS FOR 0407263.   Title:  Going Upriver: The Long War of John Kerry
# First 3 subs for 0330069 were bad. Not going any further. Title:  Blue Collar Comedy Tour: The Movie
# Downloaded subs for 1824254.   Title:  We Steal Secrets: The Story of WikiLeaks
# COULDNT FIND SUBS FOR 0095895.   Title:  Powaqqatsi
# Downloaded subs for 0192335.   Title:  Mr. Death: The Rise and Fall of Fred A. Leucht..
# COULDNT FIND SUBS FOR 0218043.   Title:  Beyond the Mat
# Downloaded subs for 4425064.   Title:  Steve Jobs: The Man in the Machine
# COULDNT FIND SUBS FOR 0107472.   Title:  The Wonderful, Horrible Life of Leni Riefenstahl
# Downloaded subs for 1787777.   Title:  Page One: Inside the New York Times
# COULDNT FIND SUBS FOR 0141986.   Title:  Wild Man Blues
# Downloaded subs for 4185572.   Title:  The Hunting Ground
# Downloaded subs for 0303297.   Title:  Amandla! A Revolution in Four-Part Harmony
# COULDNT FIND SUBS FOR 4287434.   Title:  Chasing Trane
# Downloaded subs for 1753549.   Title:  Buck
# Downloaded subs for 1638364.   Title:  The Armstrong Lie
# COULDNT FIND SUBS FOR 2049586.   Title:  Glen Campbell: I'll Be Me
# COULDNT FIND SUBS FOR 0181833.   Title:  The Source
# Downloaded subs for 1683876.   Title:  Happy People: A Year in the Taiga
# Downloaded subs for 3521134.   Title:  The Look of Silence
# Downloaded subs for 0077838.   Title:  The Last Waltz
# COULDNT FIND SUBS FOR 0912583.   Title:  For the Bible Tells Me So
# Downloaded subs for 1151309.   Title:  Bigger Stronger Faster*
# Downloaded subs for 0493459.   Title:  This Film Is Not Yet Rated
# Downloaded subs for 1286798.   Title:  Unmistaken Child
# Downloaded subs for 2062996.   Title:  Something from Nothing: The Art of Rap
# Downloaded subs for 1787660.   Title:  Being Elmo: A Puppeteer's Journey
# Downloaded subs for 1319744.   Title:  The Interrupters
# Downloaded subs for 0449570.   Title:  Buddha Wild: Monk in a Hut
# Downloaded subs for 0854678.   Title:  Taxi to the Dark Side
# Downloaded subs for 2380247.   Title:  The Central Park Five
# Downloaded subs for 0099028.   Title:  American Dream
# COULDNT FIND SUBS FOR 1286800.   Title:  Harvard Beats Yale 29-29
# COULDNT FIND SUBS FOR 0775566.   Title:  The War Tapes
# Downloaded subs for 0832903.   Title:  Manufactured Landscapes
# Downloaded subs for 0473434.   Title:  49 Up
# COULDNT FIND SUBS FOR 0145394.   Title:  A Place Called Chiapas
# Downloaded subs for 5213534.   Title:  Supersonic
# Downloaded subs for 1687247.   Title:  Life in a Day
# Downloaded subs for 1864288.   Title:  Conan O'Brien Can't Stop
# Downloaded subs for 0340468.   Title:  Bus 174
# COULDNT FIND SUBS FOR 1517252.   Title:  Sweetgrass
# Downloaded subs for 0492466.   Title:  Iraq in Fragments
# Downloaded subs for 0814075.   Title:  Deliver Us from Evil
# COULDNT FIND SUBS FOR 0138052.   Title:  Rats in the Ranks
# Downloaded subs for 3675568.   Title:  Merchants of Doubt
# Downloaded subs for 1268204.   Title:  Waste Land
# Downloaded subs for 1845773.   Title:  Ai Weiwei: Never Sorry
# COULDNT FIND SUBS FOR 1396557.   Title:  Winnebago Man
# Downloaded subs for 0853096.   Title:  Death of a President
# COULDNT FIND SUBS FOR .   Title:  The Story Of Short Stack
# COULDNT FIND SUBS FOR 1503774.   Title:  Genius Within: The Inner Life of Glenn Gould
# Downloaded subs for 0380268.   Title:  Cocaine Cowboys
# COULDNT FIND SUBS FOR 0094743.   Title:  Big Time
# Downloaded subs for 0499596.   Title:  What the Bleep! Down the Rabbit Hole
# Downloaded subs for 2737310.   Title:  Mistaken for Strangers
# Downloaded subs for 2505938.   Title:  Good Ol’ Freda
# First 3 subs for 6333056 were bad. Not going any further. Title:  City of Ghosts
# Downloaded subs for 0388888.   Title:  Dig!
# COULDNT FIND SUBS FOR 1754546.   Title:  Storm Surfers 3D
# Downloaded subs for 0120126.   Title:  Sick: The Life and Death of Bob Flanagan, Supe..
# Downloaded subs for 1781784.   Title:  Burn
# COULDNT FIND SUBS FOR 0427380.   Title:  In the Face of Evil: Reagan's War in Word and Deed
# COULDNT FIND SUBS FOR 7207238.   Title:  Jane
# COULDNT FIND SUBS FOR 0913958.   Title:  Jimmy Carter Man from Plains
# Downloaded subs for 1152822.   Title:  Freakonomics
# Downloaded subs for 1334510.   Title:  Afghan Star
# COULDNT FIND SUBS FOR .   Title:  The Story Of Short Stack
# Downloaded subs for 1398949.   Title:  Blank City
# COULDNT FIND SUBS FOR 0334416.   Title:  Stevie
# COULDNT FIND SUBS FOR 0492447.   Title:  Black Gold
# COULDNT FIND SUBS FOR 1787816.   Title:  The Last Mountain
# Downloaded subs for 1179947.   Title:  American: The Bill Hicks Story
# Downloaded subs for 1322313.   Title:  Sunshine Superman
# Downloaded subs for 1112115.   Title:  King Corn
# COULDNT FIND SUBS FOR 0216731.   Title:  Edgeplay: A Film About The Runaways
# Downloaded subs for 1990352.   Title:  The Island President
# Downloaded subs for 0970521.   Title:  Turtle: The Incredible Journey
# COULDNT FIND SUBS FOR 1541666.   Title:  Circo
# COULDNT FIND SUBS FOR 1746153.   Title:  Crime After Crime
# COULDNT FIND SUBS FOR 0430916.   Title:  Beautiful Losers
# COULDNT FIND SUBS FOR .   Title:  The Story Of Short Stack
# COULDNT FIND SUBS FOR 2007995.   Title:  Screaming in High Heels: The Rise & Fall of th..
# Downloaded subs for 3268458.   Title:  The Internet's Own Boy: The Story of Aaron Swartz
# COULDNT FIND SUBS FOR 0264802.   Title:  Live Nude Girls Unite!
# Downloaded subs for 3270538.   Title:  Requiem for the American Dream
# COULDNT FIND SUBS FOR 1276943.   Title:  Bringing Godzilla Down to Size
# COULDNT FIND SUBS FOR 2234315.   Title:  Occupy Unmasked
# COULDNT FIND SUBS FOR 1172957.   Title:  How to Live Forever
# COULDNT FIND SUBS FOR 0150338.   Title:  Divine Trash
# Downloaded subs for 0360216.   Title:  The Year of the Yao
# Downloaded subs for 1277936.   Title:  Cropsey
# Downloaded subs for 2608732.   Title:  The Pirate Bay: Away From Keyboard
# Downloaded subs for 4425258.   Title:  My Country, My Country
# COULDNT FIND SUBS FOR 4526922.   Title:  The Unknowns
# COULDNT FIND SUBS FOR 0805604.   Title:  Sacco and Vanzetti
# Downloaded subs for 0071604.   Title:  Hearts and Minds
# COULDNT FIND SUBS FOR 1787797.   Title:  Sing Your Song
# Downloaded subs for 3317522.   Title:  The Nightmare
# COULDNT FIND SUBS FOR 0756727.   Title:  Who Is Harry Nilsson (And Why Is Everybody Tal..
# COULDNT FIND SUBS FOR 4079142.   Title:  Peace Officer
# COULDNT FIND SUBS FOR 1638979.   Title:  Hey, Boo: Harper Lee & To Kill a Mockingbird
# COULDNT FIND SUBS FOR 1213832.   Title:  Nursery University
# COULDNT FIND SUBS FOR 2035599.   Title:  Pink Ribbons, Inc.
# Downloaded subs for 1510907.   Title:  Behind the Burly Q
# COULDNT FIND SUBS FOR 0447016.   Title:  Emmanuel's Gift
# Downloaded subs for 1503776.   Title:  Hugh Hefner: Playboy, Activist and Rebel
# COULDNT FIND SUBS FOR 0175844.   Title:  Lenny Bruce: Swear to Tell the Truth
# Downloaded subs for 1623008.   Title:  The Arbor
# COULDNT FIND SUBS FOR .   Title:  The Story Of Short Stack
# COULDNT FIND SUBS FOR 2358838.   Title:  Anton's Right Here
# COULDNT FIND SUBS FOR 0486585.   Title:  Fuck
# COULDNT FIND SUBS FOR 0424496.   Title:  Three of Hearts: A Postmodern Family
# COULDNT FIND SUBS FOR 5278464.   Title:  Holy Hell
# COULDNT FIND SUBS FOR 0468528.   Title:  One Bright Shining Moment
# COULDNT FIND SUBS FOR 1202566.   Title:  Gotta Dance
# Encountered double of 2293640. Title:  Minions
# Encountered double of 0435761. Title:  Toy Story 3
# Encountered double of 3469046. Title:  Despicable Me 3
# Encountered double of 2277860. Title:  Finding Dory
# Encountered double of 2948356. Title:  Zootopia
# Encountered double of 1690953. Title:  Despicable Me 2
# Encountered double of 0298148. Title:  Shrek 2
# Encountered double of 1080016. Title:  Ice Age: Dawn of the Dinosaurs
# Encountered double of 2250912. Title:  Spider-Man: Homecoming
# Encountered double of 1667889. Title:  Ice Age: Continental Drift
# Encountered double of 3896198. Title:  Guardians of the Galaxy Vol. 2
# Encountered double of 2096673. Title:  Inside Out
# Encountered double of 0413267. Title:  Shrek the Third
# Encountered double of 1790809. Title:  Pirates of the Caribbean: Dead Men Tell No Tales
# Encountered double of 1431045. Title:  Deadpool
# Encountered double of 0892791. Title:  Shrek Forever After
# Encountered double of 1049413. Title:  Up
# Encountered double of 0109830. Title:  Forrest Gump
# Encountered double of 0438097. Title:  Ice Age: The Meltdown
# Encountered double of 2245084. Title:  Big Hero 6
# Encountered double of 3521164. Title:  Moana
# Encountered double of 3470600. Title:  Sing
# Encountered double of 0441773. Title:  Kung Fu Panda
# Encountered double of 1409024. Title:  Men in Black 3
# Encountered double of 0382932. Title:  Ratatouille
# Encountered double of 0795421. Title:  Mamma Mia!
# Encountered double of 1646971. Title:  How to Train Your Dragon 2
# Encountered double of 0119654. Title:  Men in Black
# Encountered double of 0481499. Title:  The Croods
# Encountered double of 0477347. Title:  Night at the Museum
# Done. Writing Sub_data to file.

# %%
read_data=pd.read_hdf('Sub_data.h5', 'subs')
len(read_data.columns.levels[0])
# Out:
# 1601
